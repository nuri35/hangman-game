# %% [markdown]
# <a href="https://colab.research.google.com/github/nuri35/hangman-game/blob/main/hangman-game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import time

print("\n uygulamamız 1.2 versiyon olarak güncellenmiştir.\n\n")
print("\n isteğe bağlı olarak Lütfen sisteme giriş yapmak için size verilen güvenlik adlardan birini giriniz.\n\n")

print("uygulama açılıyor lutfen 2sn bekleyınız")
time.sleep(4)
print("başlıyabilirsiniz")

sıfreler = ["bilim", "erişim", "veri", "eğitim"]
kavram = input("Bir güvenlik şifresi giriniz: ")
if kavram in sıfreler:
    print(kavram + " güvenlik şifresi dogru !")

print("Programa devam edebilirsiniz")

print("\n uygulamamıza hoşgeldınız sizler için her gun duzenlı olarak uygulamamızı geliştirmeye çalışıyoruz.\n\n")

time.sleep(4)
print("hazııııııırrrmııııısın")
while True:
    kelimeler = random.choice(["armut", "istanbul", "Malatya", "karpuz"])
    kelimeler = kelimeler.upper()
    harfsayisi = len(kelimeler)
    print("\nkelimemiz {} harflidir.\n\n".format(harfsayisi))

    tahminler = []
    hata = []

    deneme = 3

    while deneme > 0:

        tabela = ""

        for harf in kelimeler:
            if harf in tahminler:
                tabela = tabela + harf
            else:
                tabela = tabela + "_"
        if tabela == kelimeler:
            print("kelimeyi dogru bıldın bravo")
            time.sleep(2)
            break

        print("kelimeyi tahmin ediniz", tabela)
        time.sleep(2)
        print(deneme, "canın kaldı")
        time.sleep(2)

        tahmin = input("bir harf tahmin et\n>>>")
        tahmin = tahmin.upper()

        if tahmin == kelimeler:
            print("bravo")
            time.sleep(4)
            break

        if tahmin in tahminler or tahmin in hata:
            print("{} daha once soylendi.Lutfen Baska Bir Harf Soyle ".format(tahmin))
            time.sleep(2)
        elif tahmin in kelimeler:
            rpt = kelimeler.count(tahmin)
            print("dogru bravo..{0} harfi kelimemiz içerisinde {1} kere geçiyor".format(tahmin, rpt))
            tahminler.append(tahmin)

        else:
            print("yanlıs. kelimede bu harf yok")
            hata.append(tahmin)
            deneme = deneme - 1

    if deneme == 0:
        print("hakkınız kalmadı maalesef")
        print("kelimemiz {}".format(kelimeler))

    print("Oyundan sonlandırmak Istiyorsaniz\n'H' tusuna basiniz\nDevam Etmek Icin Baska Bir Tusa Basiniz ")
    devam = input(">>>>")
    devam = devam.upper()

    if devam == "H":
        print("oyun sonlandırıldı")
        break

    else:
        continue
# Out:
#  uygulamamız 1.2 versiyon olarak güncellenmiştir.
#
#
#
#  isteğe bağlı olarak Lütfen sisteme giriş yapmak için size verilen güvenlik adlardan birini giriniz.
#
#
# uygulama açılıyor lutfen 2sn bekleyınız
# başlıyabilirsiniz
# Programa devam edebilirsiniz
#
#  uygulamamıza hoşgeldınız sizler için her gun duzenlı olarak uygulamamızı geliştirmeye çalışıyoruz.
#
#
# hazııııııırrrmııııısın
#
# kelimemiz 8 harflidir.
#
#
# kelimeyi tahmin ediniz ________
# 3 canın kaldı
# dogru bravo..S harfi kelimemiz içerisinde 1 kere geçiyor
# kelimeyi tahmin ediniz _S______
# 3 canın kaldı
# dogru bravo..A harfi kelimemiz içerisinde 1 kere geçiyor
# kelimeyi tahmin ediniz _S_A____
# 3 canın kaldı
# yanlıs. kelimede bu harf yok
# kelimeyi tahmin ediniz _S_A____
# 2 canın kaldı
# dogru bravo..T harfi kelimemiz içerisinde 1 kere geçiyor
# kelimeyi tahmin ediniz _STA____
# 2 canın kaldı
# yanlıs. kelimede bu harf yok
# kelimeyi tahmin ediniz _STA____
# 1 canın kaldı
# H daha once soylendi.Lutfen Baska Bir Harf Soyle
# kelimeyi tahmin ediniz _STA____
# 1 canın kaldı
# yanlıs. kelimede bu harf yok
# hakkınız kalmadı maalesef
# kelimemiz ISTANBUL
# Oyundan sonlandırmak Istiyorsaniz
# 'H' tusuna basiniz
# Devam Etmek Icin Baska Bir Tusa Basiniz
#
# kelimemiz 7 harflidir.
#
#
# kelimeyi tahmin ediniz _______
# 3 canın kaldı
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     624         """
# --> 625         parts = [self.recv(flags, copy=copy, track=track)]
#     626         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-be2c4e390145> in <module>()
#      50         time.sleep(2)
#      51
# ---> 52         tahmin = input("bir harf tahmin et\n>>>")
#      53         tahmin = tahmin.upper()
#      54
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:
